# %% [markdown]
# ### Prep meeting Martin

# %% [markdown]
# #### Cable capacity to be installed by 2050

# %%
import os
import sys

parent_dir = os.path.abspath('..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import pandas as pd
from constants import ENERGY_HUBS, NO_NODES, OFFSHORE_AREAS

CASE = "Base"

df_trans = pd.read_csv(f"../Results/{CASE}/results_output_transmission.csv")
df_trans
# Out:
#            BetweenNode  AndNode     Period  transmissionInvCap_MW  \
# 0          Switzerland  Austria  2020-2025           0.000000e+00
# 1          Switzerland  Austria  2025-2030           0.000000e+00
# 2          Switzerland  Austria  2030-2035           3.720390e+02
# 3          Switzerland  Austria  2035-2040           6.279607e+02
# 4          Switzerland  Austria  2040-2045           1.000000e+03
# ...                ...      ...        ...                    ...
# 3819  EnergyhubCentral  Germany  2035-2040           1.613436e+03
# 3820  EnergyhubCentral  Germany  2040-2045           6.646874e+03
# 3821  EnergyhubCentral  Germany  2045-2050           7.535213e-04
# 3822  EnergyhubCentral  Germany  2050-2055           3.552977e-07
# 3823  EnergyhubCentral  Germany  2055-2060           2.322881e-05
#
#       transmissionInstalledCap_MW  DiscountedInvestmentCost_EuroPerMW  \
# 0                     1200.000000                        0.000000e+00
# 1                     1200.000000                        0.000000e+00
# 2                     1572.039045                        8.907213e+07
# 3                     2199.999777                        1.080012e+08
# 4                     3199.999919                        1.191550e+08
# ...                           ...                                 ...
# 3819                 23353.125649                        5.102150e+08
# 3820                 29999.999161                        1.045510e+09
# 3821                 29999.999915                        7.734780e+01
# 3822                 29999.999915                        2.125838e-02
# 3823                 29999.999938                        6.105747e-01
#
#       transmissionExpectedAnnualVolume_GWh  ExpectedAnnualLosses_GWh
# 0                              1668.053069                 50.041592
# 1                              3884.671243                116.540137
# 2                              6666.335916                199.990077
# 3                              9835.862528                295.075876
# 4                             16397.484301                491.924529
# ...                                    ...                       ...
# 3819                         169373.883876               5081.216516
# 3820                         158650.052009               4759.501560
# 3821                         181735.461826               5452.063855
# 3822                         164674.774259               4940.243228
# 3823                         189032.405109               5670.972153
#
# [3824 rows x 8 columns]

# %% [markdown]
# Define offshore and NO nodes

# %%
NO_ONSHORE_NODES =[f"NO{i}" for i in range(1, 6)]
NO_OFFSHORE_NODES = NO_NODES + [hub.replace(" ", "") for hub in ENERGY_HUBS]

# %% [markdown]
# Define new tables;
# 1) All offshore connections
# 2) Offshore NO-connections (only NO offshore areas incl. hubs to look at offshore cables)

# %%
#1
df_trans_offshore = df_trans[(df_trans["BetweenNode"].isin(OFFSHORE_AREAS)) | (df_trans["AndNode"].isin(OFFSHORE_AREAS))]\
                        .reset_index(drop=True)
df_trans_offshore
# Out:
#            BetweenNode       AndNode     Period  transmissionInvCap_MW  \
# 0           MorayFirth  FirthofForth  2020-2025           4.018470e-04
# 1           MorayFirth  FirthofForth  2025-2030           5.106020e-05
# 2           MorayFirth  FirthofForth  2030-2035           1.122781e-03
# 3           MorayFirth  FirthofForth  2035-2040           1.748220e+01
# 4           MorayFirth  FirthofForth  2040-2045           1.894376e+02
# ...                ...           ...        ...                    ...
# 3139  EnergyhubCentral       Germany  2035-2040           1.613436e+03
# 3140  EnergyhubCentral       Germany  2040-2045           6.646874e+03
# 3141  EnergyhubCentral       Germany  2045-2050           7.535213e-04
# 3142  EnergyhubCentral       Germany  2050-2055           3.552977e-07
# 3143  EnergyhubCentral       Germany  2055-2060           2.322881e-05
#
#       transmissionInstalledCap_MW  DiscountedInvestmentCost_EuroPerMW  \
# 0                        0.000402                        2.529983e+02
# 1                        0.000453                        2.403581e+01
# 2                        0.001576                        3.032513e+02
# 3                       17.483777                        3.391927e+06
# 4                      206.921372                        1.828210e+07
# ...                           ...                                 ...
# 3139                 23353.125649                        5.102150e+08
# 3140                 29999.999161                        1.045510e+09
# 3141                 29999.999915                        7.734780e+01
# 3142                 29999.999915                        2.125838e-02
# 3143                 29999.999938                        6.105747e-01
#
#       transmissionExpectedAnnualVolume_GWh  ExpectedAnnualLosses_GWh
# 0                                 0.002420                  0.000073
# 1                                 0.002746                  0.000082
# 2                                 0.007299                  0.000219
# 3                                27.321571                  0.819647
# 4                               237.938590                  7.138158
# ...                                    ...                       ...
# 3139                         169373.883876               5081.216516
# 3140                         158650.052009               4759.501560
# 3141                         181735.461826               5452.063855
# 3142                         164674.774259               4940.243228
# 3143                         189032.405109               5670.972153
#
# [3144 rows x 8 columns]

# %%
#2
df_trans_NO = df_trans[((df_trans["BetweenNode"].isin(NO_OFFSHORE_NODES)) & (df_trans["AndNode"].isin(NO_OFFSHORE_NODES))) | \
                       ((df_trans["BetweenNode"].isin(NO_ONSHORE_NODES)) & (df_trans["AndNode"].isin(NO_OFFSHORE_NODES))) | \
                        ((df_trans["BetweenNode"].isin(NO_OFFSHORE_NODES)) & (df_trans["AndNode"].isin(NO_ONSHORE_NODES)))]\
                        .reset_index(drop=True)
df_trans_NO
# Out:
#            BetweenNode    AndNode     Period  transmissionInvCap_MW  \
# 0            NordvestA  NordvestC  2020-2025               0.000177
# 1            NordvestA  NordvestC  2025-2030               0.000107
# 2            NordvestA  NordvestC  2030-2035               0.000366
# 3            NordvestA  NordvestC  2035-2040               0.000098
# 4            NordvestA  NordvestC  2040-2045            1482.263959
# ...                ...        ...        ...                    ...
# 1371  EnergyhubCentral        NO2  2035-2040               0.000013
# 1372  EnergyhubCentral        NO2  2040-2045             607.888246
# 1373  EnergyhubCentral        NO2  2045-2050               0.000002
# 1374  EnergyhubCentral        NO2  2050-2055               0.000001
# 1375  EnergyhubCentral        NO2  2055-2060               0.000002
#
#       transmissionInstalledCap_MW  DiscountedInvestmentCost_EuroPerMW  \
# 0                        0.000177                        1.615780e+02
# 1                        0.000285                        7.322442e+01
# 2                        0.000651                        1.432945e+02
# 3                        0.000749                        2.746744e+01
# 4                     1482.264707                        2.071536e+08
# ...                           ...                                 ...
# 1371                   253.106190                        2.360263e+00
# 1372                   860.994437                        5.354308e+07
# 1373                   860.994443                        8.723335e-02
# 1374                   860.994426                        4.914014e-02
# 1375                   860.994441                        3.097121e-02
#
#       transmissionExpectedAnnualVolume_GWh  ExpectedAnnualLosses_GWh
# 0                                 0.001310                  0.000039
# 1                                 0.002009                  0.000060
# 2                                 0.004180                  0.000125
# 3                                 0.004881                  0.000146
# 4                              5320.546672                159.616400
# ...                                    ...                       ...
# 1371                           1514.685845                 45.440575
# 1372                           4249.211299                127.476339
# 1373                           3870.111253                116.103338
# 1374                           4304.481679                129.134450
# 1375                           3988.959110                119.668773
#
# [1376 rows x 8 columns]

# %% [markdown]
# #### Initial transmission capacity (2023)

# %%
# First period updated with current installed capacity, threshold installed cap > 1 MW
df_trans_offshore_2023 = df_trans_offshore[(df_trans_offshore["Period"] == "2020-2025") & \
                                           (df_trans_offshore["transmissionInstalledCap_MW"] > 1)].reset_index(drop=True)
df_trans_NO_2023 = df_trans_NO[(df_trans_NO["Period"] == "2020-2025") & \
                                           (df_trans_NO["transmissionInstalledCap_MW"] > 1)].reset_index(drop=True)

initial_cap_trans_offshore_2023 = df_trans_offshore_2023["transmissionInstalledCap_MW"].sum() \
                                    - df_trans_offshore_2023["transmissionInvCap_MW"].sum()
initial_cap_trans_NO_2023 = df_trans_NO_2023["transmissionInstalledCap_MW"].sum() \
                                    - df_trans_NO_2023["transmissionInvCap_MW"].sum()

print(f"Initial trans capacity 2023 all offshore areas: {round(initial_cap_trans_offshore_2023 / 1000, 1)} GW")
print(f"Initial trans capacity 2023 NO areas: {round(initial_cap_trans_NO_2023 / 1000, 1)} GW")
# Out:
# Initial trans capacity 2023 all offshore areas: 19.4 GW
# Initial trans capacity 2023 NO areas: 0.0 GW

# %% [markdown]
# ##### Transmission capacity installed in 2050

# %%
# First period updated with current installed capacity, threshold installed cap > 1 MW
df_trans_offshore_2050 = df_trans_offshore[(df_trans_offshore["Period"] == "2050-2055") & \
                                           (df_trans_offshore["transmissionInstalledCap_MW"] > 1)].reset_index(drop=True)
df_trans_NO_2050 = df_trans_NO[(df_trans_NO["Period"] == "2050-2055") & \
                                           (df_trans_NO["transmissionInstalledCap_MW"] > 1)].reset_index(drop=True)

cap_trans_offshore_2050 = df_trans_offshore_2050["transmissionInstalledCap_MW"].sum() \
                                    - df_trans_offshore_2050["transmissionInvCap_MW"].sum()
cap_trans_NO_2050 = df_trans_NO_2050["transmissionInstalledCap_MW"].sum() \
                                    - df_trans_NO_2050["transmissionInvCap_MW"].sum()

print(f"Initial trans capacity 2050 all offshore areas: {round(cap_trans_offshore_2050 / 1000, 1)} GW")
print(f"Initial trans capacity 2050 NO areas: {round(cap_trans_NO_2050 / 1000, 1)} GW\n")

# New cable capacity needed
print(f"New cable trans capacity needed by 2050 all offshore areas: {round((cap_trans_offshore_2050-initial_cap_trans_offshore_2023) / 1000, 1)} GW")
print(f"New cable trans capacity needed by 2050 NO areas: {round((cap_trans_NO_2050-initial_cap_trans_NO_2023) / 1000, 1)} GW")
# Out:
# Initial trans capacity 2050 all offshore areas: 411.4 GW
# Initial trans capacity 2050 NO areas: 132.4 GW
#
# New cable trans capacity needed by 2050 all offshore areas: 392.0 GW
# New cable trans capacity needed by 2050 NO areas: 132.4 GW

# %% [markdown]
# #### Compare to production capacity

# %%
df_prod = pd.read_csv(f"../Results/{CASE}/results_output_gen.csv")
df_prod
# Out:
#           Node         GeneratorType     Period  genInvCap_MW  \
# 0      BosniaH      Liginiteexisting  2020-2025  0.000000e+00
# 1      BosniaH      Liginiteexisting  2025-2030  0.000000e+00
# 2      BosniaH      Liginiteexisting  2030-2035  0.000000e+00
# 3      BosniaH      Liginiteexisting  2035-2040  0.000000e+00
# 4      BosniaH      Liginiteexisting  2040-2045  0.000000e+00
# ...        ...                   ...        ...           ...
# 5899  SørvestD  Windoffshorefloating  2035-2040  1.664920e-05
# 5900  SørvestD  Windoffshorefloating  2040-2045  2.285531e-04
# 5901  SørvestD  Windoffshorefloating  2045-2050  9.332931e-03
# 5902  SørvestD  Windoffshorefloating  2050-2055  9.369810e-07
# 5903  SørvestD  Windoffshorefloating  2055-2060  8.311450e-06
#
#       genInstalledCap_MW  genExpectedCapacityFactor  \
# 0            1888.000000               7.500000e-01
# 1            1161.846154               7.260993e-01
# 2             780.615385               6.397329e-01
# 3             544.615385               3.455009e-03
# 4             377.600000               5.164681e-08
# ...                  ...                        ...
# 5899            0.000379               3.337542e-01
# 5900            0.000607               3.410637e-01
# 5901            0.009894               4.120701e-01
# 5902            0.009851               3.574964e-01
# 5903            0.009587               3.981640e-01
#
#       DiscountedInvestmentCost_Euro  genExpectedAnnualProduction_GWh
# 0                          0.000000                     12404.159667
# 1                          0.000000                      7390.073347
# 2                          0.000000                      4374.615676
# 3                          0.000000                        16.483265
# 4                          0.000000                         0.000171
# ...                             ...                              ...
# 5899                      25.539036                         0.001107
# 5900                     224.350706                         0.001813
# 5901                    5899.940148                         0.035716
# 5902                       0.337566                         0.030851
# 5903                       1.315462                         0.033438
#
# [5904 rows x 8 columns]

# %%
#1
df_prod_offshore = df_prod[(df_prod["Node"].isin(OFFSHORE_AREAS))].reset_index(drop=True)
df_prod_offshore
# Out:
#            Node         GeneratorType     Period  genInvCap_MW  \
# 0    MorayFirth  Windoffshoregrounded  2020-2025  1.420744e-05
# 1    MorayFirth  Windoffshoregrounded  2025-2030  3.105658e-08
# 2    MorayFirth  Windoffshoregrounded  2030-2035  5.943217e+01
# 3    MorayFirth  Windoffshoregrounded  2035-2040  1.192544e+03
# 4    MorayFirth  Windoffshoregrounded  2040-2045  3.625024e+03
# ..          ...                   ...        ...           ...
# 491    SørvestD  Windoffshorefloating  2035-2040  1.664920e-05
# 492    SørvestD  Windoffshorefloating  2040-2045  2.285531e-04
# 493    SørvestD  Windoffshorefloating  2045-2050  9.332931e-03
# 494    SørvestD  Windoffshorefloating  2050-2055  9.369810e-07
# 495    SørvestD  Windoffshorefloating  2055-2060  8.311450e-06
#
#      genInstalledCap_MW  genExpectedCapacityFactor  \
# 0            588.000014                   0.516249
# 1            588.000014                   0.442946
# 2            647.432152                   0.365594
# 3           1839.975696                   0.378714
# 4           5464.999994                   0.342613
# ..                  ...                        ...
# 491            0.000379                   0.333754
# 492            0.000607                   0.341064
# 493            0.009894                   0.412070
# 494            0.009851                   0.357496
# 495            0.009587                   0.398164
#
#      DiscountedInvestmentCost_Euro  genExpectedAnnualProduction_GWh
# 0                     5.027223e+01                      2659.134186
# 1                     8.610321e-02                      2281.562819
# 2                     9.519825e+07                      2073.468435
# 3                     1.496701e+09                      6104.179927
# 4                     2.965310e+09                     16402.054758
# ..                             ...                              ...
# 491                   2.553904e+01                         0.001107
# 492                   2.243507e+02                         0.001813
# 493                   5.899940e+03                         0.035716
# 494                   3.375657e-01                         0.030851
# 495                   1.315462e+00                         0.033438
#
# [496 rows x 8 columns]

# %%
#2
df_prod_NO = df_prod[df_prod["Node"].isin(NO_OFFSHORE_NODES)].reset_index(drop=True)
df_prod_NO
# Out:
#           Node         GeneratorType     Period  genInvCap_MW  \
# 0    NordvestA  Windoffshoregrounded  2020-2025  0.000000e+00
# 1    NordvestA  Windoffshoregrounded  2025-2030  0.000000e+00
# 2    NordvestA  Windoffshoregrounded  2030-2035  0.000000e+00
# 3    NordvestA  Windoffshoregrounded  2035-2040  0.000000e+00
# 4    NordvestA  Windoffshoregrounded  2040-2045  0.000000e+00
# ..         ...                   ...        ...           ...
# 315   SørvestD  Windoffshorefloating  2035-2040  1.664920e-05
# 316   SørvestD  Windoffshorefloating  2040-2045  2.285531e-04
# 317   SørvestD  Windoffshorefloating  2045-2050  9.332931e-03
# 318   SørvestD  Windoffshorefloating  2050-2055  9.369810e-07
# 319   SørvestD  Windoffshorefloating  2055-2060  8.311450e-06
#
#      genInstalledCap_MW  genExpectedCapacityFactor  \
# 0              0.000000                   0.000000
# 1              0.000000                   0.000000
# 2              0.000000                   0.000000
# 3              0.000000                   0.000000
# 4              0.000000                   0.000000
# ..                  ...                        ...
# 315            0.000379                   0.333754
# 316            0.000607                   0.341064
# 317            0.009894                   0.412070
# 318            0.009851                   0.357496
# 319            0.009587                   0.398164
#
#      DiscountedInvestmentCost_Euro  genExpectedAnnualProduction_GWh
# 0                         0.000000                         0.000000
# 1                         0.000000                         0.000000
# 2                         0.000000                         0.000000
# 3                         0.000000                         0.000000
# 4                         0.000000                         0.000000
# ..                             ...                              ...
# 315                      25.539036                         0.001107
# 316                     224.350706                         0.001813
# 317                    5899.940148                         0.035716
# 318                       0.337566                         0.030851
# 319                       1.315462                         0.033438
#
# [320 rows x 8 columns]

# %% [markdown]
# #### Initial production capacity (2023)

# %%
# First period updated with current installed capacity, threshold installed cap > 1 MW
df_prod_offshore_2023 = df_prod_offshore[(df_prod_offshore["Period"] == "2020-2025") & \
                                           (df_prod_offshore["genInstalledCap_MW"] > 1)].reset_index(drop=True)
df_prod_NO_2023 = df_prod_NO[(df_prod_NO["Period"] == "2020-2025") & \
                                           (df_prod_NO["genInstalledCap_MW"] > 1)].reset_index(drop=True)

initial_cap_prod_offshore_2023 = df_prod_offshore_2023["genInstalledCap_MW"].sum() \
                                    - df_prod_offshore_2023["genInvCap_MW"].sum()
initial_cap_prod_NO_2023 = df_prod_NO_2023["genInstalledCap_MW"].sum() \
                                    - df_prod_NO_2023["genInvCap_MW"].sum()

print(f"Initial prod capacity 2023 all offshore areas: {round(initial_cap_prod_offshore_2023 / 1000, 1)} GW")
print(f"Initial prod capacity 2023 NO areas: {round(initial_cap_prod_NO_2023 / 1000, 1)} GW")
# Out:
# Initial prod capacity 2023 all offshore areas: 19.4 GW
# Initial prod capacity 2023 NO areas: 0.0 GW

# %% [markdown]
# #### Production capacity installed 2050

# %%
# First period updated with current installed capacity, threshold installed cap > 1 MW
df_prod_offshore_2050 = df_prod_offshore[(df_prod_offshore["Period"] == "2050-2055") & \
                                           (df_prod_offshore["genInstalledCap_MW"] > 1)].reset_index(drop=True)
df_prod_NO_2050 = df_prod_NO[(df_prod_NO["Period"] == "2050-2055") & \
                                           (df_prod_NO["genInstalledCap_MW"] > 1)].reset_index(drop=True)

cap_prod_offshore_2050 = df_prod_offshore_2050["genInstalledCap_MW"].sum() \
                                    - df_prod_offshore_2050["genInvCap_MW"].sum()
cap_prod_NO_2050 = df_prod_NO_2050["genInstalledCap_MW"].sum() \
                                    - df_prod_NO_2050["genInvCap_MW"].sum()

print(f"Initial prod capacity 2050 all offshore areas: {round(cap_prod_offshore_2050 / 1000, 1)} GW")
print(f"Initial prod capacity 2050 NO areas: {round(cap_prod_NO_2050 / 1000, 1)} GW\n")

# New cable capacity needed
print(f"New prod capacity needed by 2050 all offshore areas: {round((cap_prod_offshore_2050-initial_cap_prod_offshore_2023) / 1000, 1)} GW")
print(f"New prod capacity needed by 2050 NO areas: {round((cap_prod_NO_2050-initial_cap_prod_NO_2023) / 1000, 1)} GW")
# Out:
# Initial prod capacity 2050 all offshore areas: 226.5 GW
# Initial prod capacity 2050 NO areas: 103.3 GW
#
# New prod capacity needed by 2050 all offshore areas: 207.1 GW
# New prod capacity needed by 2050 NO areas: 103.3 GW

# %% [markdown]
# #### Additional trans capacity above max prod

# %%
add_trans_cap_offshore_2023 = initial_cap_trans_offshore_2023 - initial_cap_prod_offshore_2023
add_trans_cap_NO_2023 = initial_cap_trans_NO_2023 - initial_cap_prod_NO_2023

add_trans_cap_offshore_2050 = cap_trans_offshore_2050 - cap_prod_offshore_2050
add_trans_cap_NO_2050 = cap_trans_NO_2050 - cap_prod_NO_2050

# Additional cap above max prod (abs)
print(f"Additional trans cap above max prod 2023 all offshore areas: {round((add_trans_cap_offshore_2023) / 1000, 1)} GW")
print(f"Additional trans cap above max prod 2023 NO areas: {round((add_trans_cap_NO_2023) / 1000, 1)} GW\n")
print(f"Additional trans cap above max prod 2050 all offshore areas: {round((add_trans_cap_offshore_2050) / 1000, 1)} GW")
print(f"Additional trans cap above max prod 2050 NO areas: {round((add_trans_cap_NO_2050) / 1000, 1)} GW\n")

# Additional cap above max prod (%)
print(f"Additional trans cap above max prod 2023 all offshore areas: {round(add_trans_cap_offshore_2023/initial_cap_prod_offshore_2023*100, 1)}%")
print(f"Additional trans cap above max prod 2023 NO areas: 0.0%\n") # Manually punched 0% since initial_cap_prod_NO_2023 = 0 (DIV0-error)
print(f"Additional trans cap above max prod 2050 all offshore areas: {round(add_trans_cap_offshore_2050/cap_prod_offshore_2050*100, 1)}%")
print(f"Additional trans cap above max prod 2050 NO areas: {round(add_trans_cap_NO_2050/cap_prod_NO_2050*100, 1)}%")
# Out:
# Additional trans cap above max prod 2023 all offshore areas: -0.0 GW
# Additional trans cap above max prod 2023 NO areas: 0.0 GW
#
# Additional trans cap above max prod 2050 all offshore areas: 184.9 GW
# Additional trans cap above max prod 2050 NO areas: 29.1 GW
#
# Additional trans cap above max prod 2023 all offshore areas: -0.0%
# Additional trans cap above max prod 2023 NO areas: 0.0%
#
# Additional trans cap above max prod 2050 all offshore areas: 81.6%
# Additional trans cap above max prod 2050 NO areas: 28.2%

# %% [markdown]
# ### Curtailment of offshore wind areas

# %% [markdown]
# In this work, curtailment is defined as the unused available power from intermittent renewable sources.

# %%
df_curt = pd.read_csv(f"../Results/{CASE}/results_output_curtailed_prod.csv")
df_curt
# Out:
#          Node       RESGeneratorType     Period  \
# 0     Austria  Hydrorun-of-the-river  2020-2025
# 1     Austria  Hydrorun-of-the-river  2025-2030
# 2     Austria  Hydrorun-of-the-river  2030-2035
# 3     Austria  Hydrorun-of-the-river  2035-2040
# 4     Austria  Hydrorun-of-the-river  2040-2045
# ...       ...                    ...        ...
# 1619      NO5                  Solar  2035-2040
# 1620      NO5                  Solar  2040-2045
# 1621      NO5                  Solar  2045-2050
# 1622      NO5                  Solar  2050-2055
# 1623      NO5                  Solar  2055-2060
#
#       ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
# 0                          0.000302                        40897.516954
# 1                        164.300986                        41456.630552
# 2                      12991.859859                        53662.415670
# 3                      12463.753249                        54177.684888
# 4                      14936.792311                        55557.172309
# ...                             ...                                 ...
# 1619                       0.001300                           11.745588
# 1620                       0.010659                           12.141209
# 1621                       0.012311                            5.960668
# 1622                       0.000787                            0.003403
# 1623                       0.000836                            0.002605
#
#       Expected annual curtailment ratio of total capacity_%
# 0                                          7.387627e-07
# 1                                          3.963202e-01
# 2                                          2.421035e+01
# 3                                          2.300533e+01
# 4                                          2.688544e+01
# ...                                                 ...
# 1619                                       1.106647e-02
# 1620                                       8.779434e-02
# 1621                                       2.065312e-01
# 1622                                       2.311595e+01
# 1623                                       3.209591e+01
#
# [1624 rows x 6 columns]

# %%
#1
df_curt_offshore = df_curt[(df_curt["Node"].isin(OFFSHORE_AREAS))].reset_index(drop=True)
df_curt_offshore
# Out:
#            Node      RESGeneratorType     Period  \
# 0    MorayFirth  Windoffshoregrounded  2020-2025
# 1    MorayFirth  Windoffshoregrounded  2025-2030
# 2    MorayFirth  Windoffshoregrounded  2030-2035
# 3    MorayFirth  Windoffshoregrounded  2035-2040
# 4    MorayFirth  Windoffshoregrounded  2040-2045
# ..          ...                   ...        ...
# 491    SørvestD  Windoffshorefloating  2035-2040
# 492    SørvestD  Windoffshorefloating  2040-2045
# 493    SørvestD  Windoffshorefloating  2045-2050
# 494    SørvestD  Windoffshorefloating  2050-2055
# 495    SørvestD  Windoffshorefloating  2055-2060
#
#      ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
# 0                        16.647693                         2675.781879
# 1                       607.310139                         2888.872959
# 2                       801.265560                         2874.733995
# 3                      2274.813442                         8378.993368
# 4                      6966.061663                        23368.116422
# ..                             ...                                 ...
# 491                       0.000671                            0.001777
# 492                       0.001024                            0.002838
# 493                       0.015826                            0.051542
# 494                       0.011271                            0.042122
# 495                       0.019933                            0.053371
#
#      Expected annual curtailment ratio of total capacity_%
# 0                                             0.622162
# 1                                            21.022390
# 2                                            27.872685
# 3                                            27.149006
# 4                                            29.810112
# ..                                                 ...
# 491                                          37.728057
# 492                                          36.095709
# 493                                          30.704478
# 494                                          26.757265
# 495                                          37.348378
#
# [496 rows x 6 columns]

# %%
#2
df_curt_NO = df_curt[(df_curt["Node"].isin(NO_OFFSHORE_NODES))].reset_index(drop=True)
df_curt_NO
# Out:
#           Node      RESGeneratorType     Period  \
# 0    NordvestA  Windoffshoregrounded  2020-2025
# 1    NordvestA  Windoffshoregrounded  2025-2030
# 2    NordvestA  Windoffshoregrounded  2030-2035
# 3    NordvestA  Windoffshoregrounded  2035-2040
# 4    NordvestA  Windoffshoregrounded  2040-2045
# ..         ...                   ...        ...
# 315   SørvestD  Windoffshorefloating  2035-2040
# 316   SørvestD  Windoffshorefloating  2040-2045
# 317   SørvestD  Windoffshorefloating  2045-2050
# 318   SørvestD  Windoffshorefloating  2050-2055
# 319   SørvestD  Windoffshorefloating  2055-2060
#
#      ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
# 0                         0.000000                            0.000000
# 1                         0.000000                            0.000000
# 2                         0.000000                            0.000000
# 3                         0.000000                            0.000000
# 4                         0.000000                            0.000000
# ..                             ...                                 ...
# 315                       0.000671                            0.001777
# 316                       0.001024                            0.002838
# 317                       0.015826                            0.051542
# 318                       0.011271                            0.042122
# 319                       0.019933                            0.053371
#
#      Expected annual curtailment ratio of total capacity_%
# 0                                             0.000000
# 1                                             0.000000
# 2                                             0.000000
# 3                                             0.000000
# 4                                             0.000000
# ..                                                 ...
# 315                                          37.728057
# 316                                          36.095709
# 317                                          30.704478
# 318                                          26.757265
# 319                                          37.348378
#
# [320 rows x 6 columns]

# %% [markdown]
# #### Initial curtailment (2023)

# %%
# First period, threshold expected annual power > 0 GWh
df_curt_offshore_2023 = df_curt_offshore[(df_curt_offshore["Period"] == "2020-2025") & \
                                           (df_curt_offshore["Expected total available power_GWh"] > 0)].reset_index(drop=True)
df_curt_NO_2023 = df_curt_NO[(df_curt_NO["Period"] == "2020-2025") & \
                                           (df_curt_NO["Expected total available power_GWh"] > 0)].reset_index(drop=True)

avg_curt_offshore_2023 = df_curt_offshore_2023["Expected annual curtailment ratio of total capacity_%"].mean() 
avg_curt_NO_2023 = df_curt_NO_2023["Expected annual curtailment ratio of total capacity_%"].mean() 

print(f"Average curtailment 2023 all offshore areas: {round(avg_curt_offshore_2023, 1)}%")
print(f"Average curtailment 2023 NO areas: {round(avg_curt_NO_2023, 1)}%")
# Out:
# Average curtailment 2023 all offshore areas: 10.5%
# Average curtailment 2023 NO areas: 14.6%

# %% [markdown]
# #### Curtailment 2050

# %%
# 2050, threshold expected annual power > 0 GWh
df_curt_offshore_2050 = df_curt_offshore[(df_curt_offshore["Period"] == "2050-2055") & \
                                           (df_curt_offshore["Expected total available power_GWh"] > 0)].reset_index(drop=True)
df_curt_NO_2050 = df_curt_NO[(df_curt_NO["Period"] == "2050-2055") & \
                                           (df_curt_NO["Expected total available power_GWh"] > 0)].reset_index(drop=True)

avg_curt_offshore_2050 = df_curt_offshore_2050["Expected annual curtailment ratio of total capacity_%"].mean() 
avg_curt_NO_2050 = df_curt_NO_2050["Expected annual curtailment ratio of total capacity_%"].mean() 

print(f"Average curtailment 2050 all offshore areas: {round(avg_curt_offshore_2050, 1)}%")
print(f"Average curtailment 2050 NO areas: {round(avg_curt_NO_2050, 1)}%")
# Out:
# Average curtailment 2050 all offshore areas: 19.9%
# Average curtailment 2050 NO areas: 19.4%
