# %% [markdown]
# ### Curtailment calculation of wind areas in the NS 2050

# %% [markdown]
# In this work, curtailment is defined as the unused available power from intermittent renewable sources.

# %%
import os
import sys

parent_dir = os.path.abspath('..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import pandas as pd
from constants import WIND_FARM_NODES

CASES = ["Base", "NOgrid", "NoHubs", "NoHubsNOgrid", "OnlyCentral", "OnlyEU", "OnlyNorth"]

DF_BY_CASES = dict({})

for case in CASES:
    #_df = pd.read_csv(f'curtailment/{case}_results_output_curtailed_prod.csv')
    _df = pd.read_csv(f'../Results/{case}/results_output_curtailed_prod.csv')
    DF_BY_CASES[case] = _df

DF_BY_CASES
# Out:
# {'Base':          Node       RESGeneratorType     Period  \
#  0     Austria  Hydrorun-of-the-river  2020-2025
#  1     Austria  Hydrorun-of-the-river  2025-2030
#  2     Austria  Hydrorun-of-the-river  2030-2035
#  3     Austria  Hydrorun-of-the-river  2035-2040
#  4     Austria  Hydrorun-of-the-river  2040-2045
#  ...       ...                    ...        ...
#  1619      NO5                  Solar  2035-2040
#  1620      NO5                  Solar  2040-2045
#  1621      NO5                  Solar  2045-2050
#  1622      NO5                  Solar  2050-2055
#  1623      NO5                  Solar  2055-2060
#
#        ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
#  0                          0.000302                        40897.516954
#  1                        164.300986                        41456.630552
#  2                      12991.859859                        53662.415670
#  3                      12463.753249                        54177.684888
#  4                      14936.792311                        55557.172309
#  ...                             ...                                 ...
#  1619                       0.001300                           11.745588
#  1620                       0.010659                           12.141209
#  1621                       0.012311                            5.960668
#  1622                       0.000787                            0.003403
#  1623                       0.000836                            0.002605
#
#        Expected annual curtailment ratio of total capacity_%
#  0                                          7.387627e-07
#  1                                          3.963202e-01
#  2                                          2.421035e+01
#  3                                          2.300533e+01
#  4                                          2.688544e+01
#  ...                                                 ...
#  1619                                       1.106647e-02
#  1620                                       8.779434e-02
#  1621                                       2.065312e-01
#  1622                                       2.311595e+01
#  1623                                       3.209591e+01
#
#  [1624 rows x 6 columns],
#  'NOgrid':          Node       RESGeneratorType     Period  \
#  0     Austria  Hydrorun-of-the-river  2020-2025
#  1     Austria  Hydrorun-of-the-river  2025-2030
#  2     Austria  Hydrorun-of-the-river  2030-2035
#  3     Austria  Hydrorun-of-the-river  2035-2040
#  4     Austria  Hydrorun-of-the-river  2040-2045
#  ...       ...                    ...        ...
#  1619      NO5                  Solar  2035-2040
#  1620      NO5                  Solar  2040-2045
#  1621      NO5                  Solar  2045-2050
#  1622      NO5                  Solar  2050-2055
#  1623      NO5                  Solar  2055-2060
#
#        ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
#  0                          0.000429                        40897.517105
#  1                        163.000532                        41455.330069
#  2                      12854.903107                        53481.944577
#  3                      13761.658787                        55475.590411
#  4                      15009.119166                        55557.172302
#  ...                             ...                                 ...
#  1619                       0.001415                           11.745591
#  1620                       0.007124                           12.141213
#  1621                       0.002021                            5.960671
#  1622                       0.000803                            0.008668
#  1623                       0.001050                            0.006646
#
#        Expected annual curtailment ratio of total capacity_%
#  0                                              0.000001
#  1                                              0.393196
#  2                                             24.035968
#  3                                             24.806692
#  4                                             27.015628
#  ...                                                 ...
#  1619                                           0.012046
#  1620                                           0.058675
#  1621                                           0.033903
#  1622                                           9.265024
#  1623                                          15.799099
#
#  [1624 rows x 6 columns],
#  'NoHubs':          Node       RESGeneratorType     Period  \
#  0     Austria  Hydrorun-of-the-river  2020-2025
#  1     Austria  Hydrorun-of-the-river  2025-2030
#  2     Austria  Hydrorun-of-the-river  2030-2035
#  3     Austria  Hydrorun-of-the-river  2035-2040
#  4     Austria  Hydrorun-of-the-river  2040-2045
#  ...       ...                    ...        ...
#  1619      NO5                  Solar  2035-2040
#  1620      NO5                  Solar  2040-2045
#  1621      NO5                  Solar  2045-2050
#  1622      NO5                  Solar  2050-2055
#  1623      NO5                  Solar  2055-2060
#
#        ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
#  0                          0.000306                        40897.516981
#  1                        168.575030                        41460.904599
#  2                      10944.150829                        51388.005908
#  3                      13761.659973                        55475.591611
#  4                      15009.119220                        55557.172321
#  ...                             ...                                 ...
#  1619                       0.000851                           11.745589
#  1620                       0.009853                           12.141209
#  1621                       0.003208                            5.960668
#  1622                       0.000848                            0.006848
#  1623                       0.001300                            0.005243
#
#        Expected annual curtailment ratio of total capacity_%
#  0                                          7.472298e-07
#  1                                          4.065879e-01
#  2                                          2.129709e+01
#  3                                          2.480669e+01
#  4                                          2.701563e+01
#  ...                                                 ...
#  1619                                       7.243579e-03
#  1620                                       8.115167e-02
#  1621                                       5.381614e-02
#  1622                                       1.237711e+01
#  1623                                       2.478951e+01
#
#  [1624 rows x 6 columns],
#  'NoHubsNOgrid':          Node       RESGeneratorType     Period  \
#  0     Austria  Hydrorun-of-the-river  2020-2025
#  1     Austria  Hydrorun-of-the-river  2025-2030
#  2     Austria  Hydrorun-of-the-river  2030-2035
#  3     Austria  Hydrorun-of-the-river  2035-2040
#  4     Austria  Hydrorun-of-the-river  2040-2045
#  ...       ...                    ...        ...
#  1619      NO5                  Solar  2035-2040
#  1620      NO5                  Solar  2040-2045
#  1621      NO5                  Solar  2045-2050
#  1622      NO5                  Solar  2050-2055
#  1623      NO5                  Solar  2055-2060
#
#        ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
#  0                          0.000385                        40897.517054
#  1                        167.409059                        41459.738616
#  2                      11049.503793                        51540.931155
#  3                      13761.659964                        55475.591602
#  4                      15009.119218                        55557.172317
#  ...                             ...                                 ...
#  1619                       0.001332                           11.745589
#  1620                       0.007999                           12.141207
#  1621                       0.001744                            5.960665
#  1622                       0.000706                            0.007429
#  1623                       0.000991                            0.005686
#
#        Expected annual curtailment ratio of total capacity_%
#  0                                          9.406043e-07
#  1                                          4.037871e-01
#  2                                          2.143831e+01
#  3                                          2.480669e+01
#  4                                          2.701563e+01
#  ...                                                 ...
#  1619                                       1.134317e-02
#  1620                                       6.588481e-02
#  1621                                       2.926013e-02
#  1622                                       9.501508e+00
#  1623                                       1.742380e+01
#
#  [1624 rows x 6 columns],
#  'OnlyCentral':          Node       RESGeneratorType     Period  \
#  0     Austria  Hydrorun-of-the-river  2020-2025
#  1     Austria  Hydrorun-of-the-river  2025-2030
#  2     Austria  Hydrorun-of-the-river  2030-2035
#  3     Austria  Hydrorun-of-the-river  2035-2040
#  4     Austria  Hydrorun-of-the-river  2040-2045
#  ...       ...                    ...        ...
#  1619      NO5                  Solar  2035-2040
#  1620      NO5                  Solar  2040-2045
#  1621      NO5                  Solar  2045-2050
#  1622      NO5                  Solar  2050-2055
#  1623      NO5                  Solar  2055-2060
#
#        ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
#  0                          0.002928                        40897.519616
#  1                        163.792388                        41456.121839
#  2                      13055.534286                        53700.467837
#  3                      12481.369762                        54195.301342
#  4                      15009.119199                        55557.172198
#  ...                             ...                                 ...
#  1619                       0.010752                           11.745595
#  1620                       0.078960                           12.141287
#  1621                       0.067752                            5.960747
#  1622                       0.013119                            0.097650
#  1623                       0.020551                            0.074754
#
#        Expected annual curtailment ratio of total capacity_%
#  0                                              0.000007
#  1                                              0.395098
#  2                                             24.311770
#  3                                             23.030354
#  4                                             27.015628
#  ...                                                 ...
#  1619                                           0.091543
#  1620                                           0.650339
#  1621                                           1.136641
#  1622                                          13.434444
#  1623                                          27.491512
#
#  [1624 rows x 6 columns],
#  'OnlyEU':          Node       RESGeneratorType     Period  \
#  0     Austria  Hydrorun-of-the-river  2020-2025
#  1     Austria  Hydrorun-of-the-river  2025-2030
#  2     Austria  Hydrorun-of-the-river  2030-2035
#  3     Austria  Hydrorun-of-the-river  2035-2040
#  4     Austria  Hydrorun-of-the-river  2040-2045
#  ...       ...                    ...        ...
#  1619      NO5                  Solar  2035-2040
#  1620      NO5                  Solar  2040-2045
#  1621      NO5                  Solar  2045-2050
#  1622      NO5                  Solar  2050-2055
#  1623      NO5                  Solar  2055-2060
#
#        ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
#  0                          0.001822                        40897.518485
#  1                        164.260728                        41456.590262
#  2                      13126.007356                        53782.521742
#  3                      12483.026341                        54196.957978
#  4                      15009.119181                        55557.172278
#  ...                             ...                                 ...
#  1619                       0.007622                           11.745588
#  1620                       0.057516                           12.141207
#  1621                       0.046208                            5.960667
#  1622                       0.008605                            0.054097
#  1623                       0.012212                            0.041405
#
#        Expected annual curtailment ratio of total capacity_%
#  0                                              0.000004
#  1                                              0.396223
#  2                                             24.405712
#  3                                             23.032707
#  4                                             27.015628
#  ...                                                 ...
#  1619                                           0.064889
#  1620                                           0.473722
#  1621                                           0.775212
#  1622                                          15.907458
#  1623                                          29.493019
#
#  [1624 rows x 6 columns],
#  'OnlyNorth':          Node       RESGeneratorType     Period  \
#  0     Austria  Hydrorun-of-the-river  2020-2025
#  1     Austria  Hydrorun-of-the-river  2025-2030
#  2     Austria  Hydrorun-of-the-river  2030-2035
#  3     Austria  Hydrorun-of-the-river  2035-2040
#  4     Austria  Hydrorun-of-the-river  2040-2045
#  ...       ...                    ...        ...
#  1619      NO5                  Solar  2035-2040
#  1620      NO5                  Solar  2040-2045
#  1621      NO5                  Solar  2045-2050
#  1622      NO5                  Solar  2050-2055
#  1623      NO5                  Solar  2055-2060
#
#        ExpectedAnnualCurtailment_GWh  Expected total available power_GWh  \
#  0                          0.003719                        40897.520031
#  1                        168.302958                        41460.632375
#  2                      12635.099991                        53249.252233
#  3                      12442.103179                        54156.034561
#  4                      15009.119186                        55557.172105
#  ...                             ...                                 ...
#  1619                       0.015650                           11.745594
#  1620                       0.104274                           12.141264
#  1621                       0.100175                            5.960724
#  1622                       0.019743                            0.137888
#  1623                       0.029913                            0.105633
#
#        Expected annual curtailment ratio of total capacity_%
#  0                                              0.000009
#  1                                              0.405934
#  2                                             23.728221
#  3                                             22.974546
#  4                                             27.015628
#  ...                                                 ...
#  1619                                           0.133238
#  1620                                           0.858842
#  1621                                           1.680577
#  1622                                          14.318441
#  1623                                          28.318271
#
#  [1624 rows x 6 columns]}

# %%
def curtailment_of_wind_prod(case, _df):
    df_wind_farm_nodes = _df[_df["Node"].isin(WIND_FARM_NODES)]

    # Period = 2050 
    df_wind_farm_nodes = df_wind_farm_nodes[df_wind_farm_nodes["Period"] == "2050-2055"] 

    # Exclude those with expected production below 1 GWh
    df_wind_farm_nodes = df_wind_farm_nodes[df_wind_farm_nodes["Expected total available power_GWh"] > 0].reset_index(drop=True)
    
    avg_curtailment = df_wind_farm_nodes["Expected annual curtailment ratio of total capacity_%"].mean()
    print(f"Average curtailment for case: {case} = {round(avg_curtailment, 1)}%")

# %%
for case, _df in DF_BY_CASES.items():
    curtailment_of_wind_prod(case, _df)
# Out:
# Average curtailment for case: Base = 19.9%
# Average curtailment for case: NOgrid = 13.4%
# Average curtailment for case: NoHubs = 22.0%
# Average curtailment for case: NoHubsNOgrid = 16.6%
# Average curtailment for case: OnlyCentral = 19.6%
# Average curtailment for case: OnlyEU = 19.8%
# Average curtailment for case: OnlyNorth = 20.9%
